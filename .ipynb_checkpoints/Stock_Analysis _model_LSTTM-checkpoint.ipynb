# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import pandas_datareader as datard
import yfinance as yf

# %%
from datetime import datetime
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

df = yf.download('SBIN.NS',start,end)
df = df.reset_index()
df.head(10)
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close
# 0 2022-07-27  515.299988  529.950012  512.250000  528.200012  518.131409  \
# 1 2022-07-28  533.200012  537.500000  529.549988  532.450012  522.300415
# 2 2022-07-29  535.049988  537.000000  526.750000  528.349976  518.278503
# 3 2022-08-01  529.049988  535.000000  526.400024  533.750000  523.575623
# 4 2022-08-02  531.900024  544.900024  531.099976  542.099976  531.766418
# 5 2022-08-03  541.900024  546.400024  534.650024  540.849976  530.540222
# 6 2022-08-04  543.650024  544.000000  524.200012  533.250000  523.085144
# 7 2022-08-05  535.549988  542.900024  529.000000  531.049988  520.927063
# 8 2022-08-08  524.000000  524.000000  513.849976  520.400024  510.480103
# 9 2022-08-10  521.549988  523.500000  513.400024  514.700012  504.888733
#
#      Volume
# 0  15101546
# 1  12160734
# 2  11921058
# 3   8295631
# 4  16845027
# 5  24262125
# 6  18072293
# 7  21110734
# 8  32566317
# 9  16904151

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head(10)
# Out:
#          Open        High         Low       Close    Volume
# 0  515.299988  529.950012  512.250000  528.200012  15101546
# 1  533.200012  537.500000  529.549988  532.450012  12160734
# 2  535.049988  537.000000  526.750000  528.349976  11921058
# 3  529.049988  535.000000  526.400024  533.750000   8295631
# 4  531.900024  544.900024  531.099976  542.099976  16845027
# 5  541.900024  546.400024  534.650024  540.849976  24262125
# 6  543.650024  544.000000  524.200012  533.250000  18072293
# 7  535.549988  542.900024  529.000000  531.049988  21110734
# 8  524.000000  524.000000  513.849976  520.400024  32566317
# 9  521.549988  523.500000  513.400024  514.700012  16904151

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  248.000000  248.000000  248.000000  248.000000  2.480000e+02
# mean   565.946574  570.990122  559.804435  565.331652  1.503088e+07
# std     32.179629   31.632976   32.603154   31.862174  7.385768e+06
# min    507.000000  511.750000  499.350006  505.350006  0.000000e+00
# 25%    534.549988  539.875015  527.150024  533.287491  1.001949e+07
# 50%    568.799988  574.200012  565.450012  569.274994  1.298182e+07
# 75%    594.712524  597.925018  588.200012  592.837494  1.766755e+07
# max    625.549988  629.549988  617.500000  625.500000  4.565662e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    248 non-null    float64
#  1   High    248 non-null    float64
#  2   Low     248 non-null    float64
#  3   Close   248 non-null    float64
#  4   Volume  248 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 9.8 KB

# %% [markdown]
# # Moving Average

# %%
MA10 = df.Close.rolling(10).mean()
MA10
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 243    596.049994
# 244    598.554999
# 245    600.659998
# 246    603.250000
# 247    606.339996
# Name: Close, Length: 248, dtype: float64

# %%
plt.figure(figsize = (10,5))
plt.plot(df.Close)
plt.plot(MA10, 'r')

# %%
MA20 = df.Close.rolling(20).mean()
MA50 = df.Close.rolling(50).mean()

# %%
plt.figure(figsize = (10,4))
plt.plot(df.Close)
plt.plot(MA10, 'r', label='moving avg 100')
plt.plot(MA20, 'g', label='moving avg 200')
plt.plot(MA50, 'b', label='moving avg 500')
plt.legend()
plt.title("Moving Avg. of closing stock 100days, 200days, 500days ")
# Out:
# Text(0.5, 1.0, 'Moving Avg. of closing stock 100days, 200days, 500days ')

# %% [markdown]
# # Daily Returns

# %%
daily_return = df.Close.pct_change()
daily_return
# Out:
# 0           NaN
# 1      0.008046
# 2     -0.007700
# 3      0.010221
# 4      0.015644
#          ...
# 243    0.008278
# 244    0.004146
# 245   -0.013033
# 246    0.009104
# 247    0.002276
# Name: Close, Length: 248, dtype: float64

# %%
plt.figure(figsize = (14,5))
daily_return.plot(legend=True, linestyle='dashed', marker='o')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,4))
daily_return.hist(bins = 50)
plt.title("Daily returns count")
plt.xlabel("Daily return")
plt.ylabel("counts")
# Out:
# Text(0, 0.5, 'counts')

# %% [markdown]
# # Predict Closing Price

# %%
end_date = datetime.now()
start_date = datetime(end_date.year - 10, end_date.month, end_date.day)
df_new = yf.download('SBIN.NS',start_date,end_date)
df_new = df_new.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_close = df_new.drop(['Date', 'Adj Close', 'Open', 'High', 'Low', 'Volume'], axis = 1)

# %%
len(df_close)
# Out:
# 2465

# %%
plt.figure(figsize=(14,4))
plt.title('Close Price History')
plt.plot(df_close['Close'])
plt.xlabel('Date', fontsize=10)
plt.ylabel('Close Price INR', fontsize=10)
plt.show()

# %%
train_data = pd.DataFrame(df_close['Close'])[0:int(len(df_close)*0.70)]
test_data = pd.DataFrame(df_close['Close'][int(len(df_close)*0.70):len(df_close)])

train_data.shape[0]
# Out:
# 1725

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

train_data_array = scaler.fit_transform(train_data)
train_data_array.shape[0]
# Out:
# 1725

# %%
X_train = []
y_train = []

for i in range(150,train_data_array.shape[0]):
  X_train.append(train_data_array[i-100: i])
  y_train.append(train_data_array[i, 0])


X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# **ML Model**

# %%
from keras.layer import Dense, Dropout, LSTM
from keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 from keras.layer import Dense, Dropout, LSTM
#       2 from keras.models import Sequential
#
# File c:\python39\lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File c:\python39\lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File c:\python39\lib\site-packages\keras\__internal__\backend\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# File c:\python39\lib\site-packages\keras\src\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras.src import distribute
# ---> 21 from keras.src import models
#      22 from keras.src.engine.input_layer import Input
#      23 from keras.src.engine.sequential import Sequential
#
# File c:\python39\lib\site-packages\keras\src\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.src.engine.functional import Functional
#      19 from keras.src.engine.sequential import Sequential
#      20 from keras.src.engine.training import Model
#
# File c:\python39\lib\site-packages\keras\src\engine\functional.py:23
#      20 import itertools
#      21 import warnings
# ---> 23 import tensorflow.compat.v2 as tf
#      25 from keras.src import backend
#      26 from keras.src.dtensor import layout_map as layout_map_lib
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
model = Sequential()
model.add(LSTM(units = 50, activation ='relu', return_sequences = True, input_shape = (X_train.shape[1], 1)))

model.add(Dropout(0.2))




model = Sequential()
model.add(LSTM(units = 70, activation ='relu', return_sequences = True))

model.add(Dropout(0.3))




model = Sequential()
model.add(LSTM(units = 90, activation ='relu', return_sequences = True))

model.add(Dropout(0.4))




model = Sequential()
model.add(LSTM(units = 100, activation ='relu'))

model.add(Dropout(0.5))


model.add(Dense(units = 1))

# %%
model.summary()

# %%
model.compile(optimizer = 'adam', loss= 'mean_squared_error')
model.fit(X_train, y_train, epochs=25)

# %%
model.save("stock_analysis.h5")

# %%
past_150days = train_data.tail(150)
final_df = past_150days.append(test_data, ignore_index = True)

# %%
final_df.tail()

# %%
final_data = scaler.fit_transform(final_df)

# %%
X_test = []
y_test = []
for i in range(150, final_data.shape[0]):
  X_test.append(final_data[i-150: i])
  y_test.append(final_data[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

# %%
y_pred = model.predict(X_test)

y_pred.shape

# %%
scale_factor = scaler.scale_[0]

# %%
y_pred = y_pred / scale_factor
y_test = y_test / scale_factor

# %%
plt.figure(figsize = (13,4))
plt.plot(y_test, 'g', label = 'Actual price')
plt.plot(y_pred, 'r', label = 'Predicted price')
plt.xlabel("Time")
plt.ylabel("price")
plt.legend()
